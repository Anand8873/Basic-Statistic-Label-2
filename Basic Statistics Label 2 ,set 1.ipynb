# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Question 1

# %%
data= pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])

# %%
name=['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.',
     'Lehman Brothers','Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanley',
     'Sun Microsystems','Travelers','US Airways','Warner-Lambert']

# %%
plt.pie(data,labels=name,autopct='%1.2f%%')
plt.show()

# %%
sns.boxplot(data)
# Out:
# <Axes: >

# %%
data.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 15 entries, 0 to 14
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 15 non-null     float64
# dtypes: float64(1)
# memory usage: 252.0 bytes

# %%
data.mean()
# Out:
# 33.27133333333333

# %%
data.mode()
# Out:
# 0     24.14
# 1     24.23
# 2     24.39
# 3     25.41
# 4     25.53
# 5     25.81
# 6     25.99
# 7     26.71
# 8     28.25
# 9     29.62
# 10    32.95
# 11    35.00
# 12    39.42
# 13    40.26
# 14    91.36
# dtype: float64

# %%
data.var()
# Out:
# 287.1466123809524

# %%
data.std()
# Out:
# 16.945400921222028

# %%
data.count()
# Out:
# 15

# %%
data.max()
# Out:
# 91.36

# %%
data.min()
# Out:
# 24.14

# %% [markdown]
# # Question 5

# %%
# use formula (x*p(x))

# %%
(-2000*0.1)
# Out:
# -200.0

# %%
(-1000*0.1)
# Out:
# -100.0

# %%
(0*0.2)
# Out:
# 0.0

# %%
(1000*0.2)
# Out:
# 200.0

# %%
(2000*0.3)
# Out:
# 600.0

# %%
(3000*0.1)
# Out:
# 300.0

# %%
(-200+-100+0+200+600+300)
# Out:
# 800

# %%
x=pd.Series([-200,-100,0,200,600,300])

# %%
x
# Out:
# 0   -200
# 1   -100
# 2      0
# 3    200
# 4    600
# 5    300
# dtype: int64

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
x.std()
# Out:
# 294.3920288775949

# %%
x.var()
# Out:
# 86666.66666666666

# %%
x.mean()
# Out:
# 133.33333333333334

# %%
x.mode()
# Out:
# 0   -200
# 1   -100
# 2      0
# 3    200
# 4    300
# 5    600
# dtype: int64

# %%
x.min()

# %%
x.max()

# %%
x.count()
